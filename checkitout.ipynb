# %%
import pandas as pd
df = pd.read_csv("Daten/clean/master_analysis.csv")
df = df[["name", "category", "type"]]
display(df.tail(100))
# Out:
#                                                      name   category  type
# 213725  EarPods Apple Headphones with Remote and Mic (...      Audio  5384
# 213726                                                NaN  Sonstiges   NaN
# 213727                                                NaN  Sonstiges   NaN
# 213728  EarPods Apple Headphones with Remote and Mic (...      Audio  5384
# 213729                                                NaN  Sonstiges   NaN
# ...                                                   ...        ...   ...
# 213820                                                NaN  Sonstiges   NaN
# 213821                                                NaN  Sonstiges   NaN
# 213822                                                NaN  Sonstiges   NaN
# 213823                                                NaN  Sonstiges   NaN
# 213824  EarPods Apple Headphones with Remote and Mic (...      Audio  5384
#
# [100 rows x 3 columns]
